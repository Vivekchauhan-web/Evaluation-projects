# %% [markdown]
#                                         Base Ball Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
bbdf=pd.read_csv('base_ball.csv')

# %%
bbdf
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Here we observed that there are no missing values are present in the dataset
bbdf.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#dataset contains 30 records and 17 features
bbdf.shape
# Out:
# (30, 17)

# %%
bbdf.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# here from the above information of data types all the feature are of int64 data types except ERA which is of float 64 types

# %%
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
sns.heatmap(bbdf.isnull())
# Out:
# <Axes: >

# %%
    #From the above heat map also it is clear that there are no missing values are present in the dataset

# %%
#checking for the unique value in each feature in the data set  
bbdf.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
 # Displaying first 10 records from the  dataset
bbdf.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# ...

# %%
#displaying last 10 records from the data set
bbdf.tail(10)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 20  90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21  83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22  71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23  67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24  63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# ...

# %%
bbdf.describe(include='all')
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [raw]
#  From the above statistical summary of the dataset we observed that
# 1.overall , our  data distribution appears to be relatively symmetric, with a slight left  and right skewness.
# 2. There might be chance that few outliers are present because there slightly jump has been seen from third quarile to upper fence and also mean is less than upper fence(max value)

# %%
# Here we checked for the duplicate value and it is clear that we dont have duplicate value in the dataset 
bbdf.duplicated().sum()
# Out:
# 0

# %%
for i in bbdf.columns:
    print(bbdf[i].value_counts())
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64
# R
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: count, dtype: int64
# AB
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [raw]
#                         UNIVARIATE ANALYSIS OF THE FEATURES

# %%
bbdf['W'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='W'>

# %% [markdown]
# #Here from the above obseravtion we found that this plot will show the number of games won or win accquired by different pitchers

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        plt.subplots_adjust(hspace=0.5)
        sns.distplot(bbdf[i],color='red')
        plt.xlabel(i,fontsize=14)
    count=count+1
plt.show()

# %% [markdown]
# #Here from the above observation we found that almost all the features in the distribution are normally distributed except the feature R, SO,CG and E have slight left and right  skewness in their distribution of data
# Feature H and E bipolar distribution of data are present

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        plt.subplots_adjust(hspace=0.5)
        plt.hist(bbdf[i],color='red')
        plt.xlabel(i,fontsize=14)
    count=count+1
plt.show()

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        plt.subplots_adjust(hspace=0.5)
        sns.boxplot(bbdf[i],color='red')
        plt.xlabel(i,fontsize=14)
    count=count+1
plt.show()

# %%
# From the above plot we conclude that few outliers are present in the feature R,ERA,SHO,SV and E

# %%
bbdf
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
bbdf['W'].value_counts()
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64

# %% [markdown]
# #Here from the above observation it is showing the specific  number of wins credited to specefic number of pitcher.
# #Here it is clear win count 68 is credited to 3 pitcher and also highest win count 100 is credited to one pitcher.
# win count alone only doesnt shows the pitcher performance we have to consider and evaluate various factor for the performance of pitcher

# %%
correlation=bbdf.corr()

# %%
correlation
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation,annot=True,cmap='viridis',fmt='.2f')
# Out:
# <Axes: >

# %% [raw]
# #Here from the above correlation we observerd the following information:
# 1.Target feature wins(W) is highly neagtively correlated with Earned Run Average ,Earned Run ,Run Average as this increases there is likely to have less chance of win credited to the the pitcher.
# 2. Target variable(Win) is highly positive correlated with  the feature Save in the base ball as it increased there is more likely have chance to win .
# 3.Run Average ,Earned Run and Earned Run Average is also highly negative correlated with  the Feature Save and shutout.
# 4.Run Average is highly positive correlated with Earned Run Average and Earned Run
# 5.Earned Run highly positive correlated with Earned Run Average
# 6. Shutout is also highly negative correlated with ERA,RA,and ER

# %%
            EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        plt.scatter(bbdf['W'],bbdf[i],color='red')
        plt.xlabel(i,fontsize=14)
    count+=1
plt.show()

# %%
 plt.scatter(bbdf['W'],bbdf['R'],color='red')
plt.xlabel('W',fontsize=12)
# Out:
# Text(0.5, 0, 'W')

# %% [raw]
# 1.Here from the above observation it is clear that Wins and Run Scored have positive correlation between them as the count of Run Scored increase count of win also increases.
# 2.Here Runs are scored by crossing homeplate after hitting the ball or due to walks error or other action

# %%
plt.scatter(bbdf['W'],y=bbdf['AB'],color='red')
plt.xlabel('W',fontsize=12)
plt.ylabel('AB',fontsize=12)
# Out:
# Text(0, 0.5, 'AB')

# %% [raw]
# # Here from the above observation  we conclude that there is not direct relationship between Wins and at Bat feature .if the batter hits a single ,double or triple or home run it count as at bat and it doesnt make sens as Win of the pitcher.The above scatter plot shows Wins  dont have any correlation with at bat feature.hence there is low postive correlation with the the feature at bat.

# %%
plt.scatter(bbdf['W'],bbdf['H'],color='red')
plt.xlabel('W',fontsize=12)
plt.ylabel('H',fontsize=12)
# Out:
# Text(0, 0.5, 'H')

# %% [raw]
# # here from the above observation we conclude that  ('H') has multifaceted relationship with Wins.(H) represent the number of times a batter successfully reaches base after putting the ball in play and it include either single ,double ,triples or home run and it affect both the overall individual player performance and contribute to the run producton for the team.It is not directly correlated with wins credit

# %%
plt.scatter(bbdf['W'],bbdf['ERA'],color='red')
plt.xlabel('W',fontsize=12)
plt.ylabel('ERA',fontsize=12)
# Out:
# Text(0, 0.5, 'ERA')

# %% [raw]
# # Here from the above observation we conclude that basically low ERA indicates more effective pitcher and higher ERA suggest that pitcher is struggling to prevent opposing teams from scoring.Here it clearly showing with low ERA (2.94) we have maximum count of wins(100) credited to pitcher.Win is highly negatively correlated with  the feature ERA

# %%
plt.scatter(bbdf['W'],bbdf['CG'],color='red')
plt.xlabel('W',fontsize=12)
plt.ylabel('CG',fontsize=12)
# Out:
# Text(0, 0.5, 'CG')

# %% [raw]
# # Above graph shows the moderately positive correlation between win and complete game (CG) feature

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        sns.regplot(x=bbdf['W'],y=bbdf[i],data=bbdf)
        plt.xlabel(i,fontsize=14)
    count+=1
plt.show()

# %% [raw]
# # here from the above regplot ( scatterplot with regression line ) we are visualizing the relationship between number of wins and various feature in our baseball dataset
# 1. W VS R -> It is showing the positive correlation suggest that team having more runs tends to win more games
#
# 2. W VS HR-->Here plot shows the relatioship between the no of home runs hit by team and their wins
# Home runs are powerful offensive weapons and team with more home runs often consider as well performing team
#
# 3.W VS ERA -> Here the regplot shows hows team's pitching performance affect their wins .Lower ERA indicate better pitching performance and also more wins
#
# 4 Wins Vs SB(Stolen Bases) -> Team with  effective base running may have an more advantage and impacts on win

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        sns.violinplot(x=bbdf['W'],y=bbdf[i],data=bbdf)
        plt.xlabel(i,fontsize=14)
    count+=1
plt.show()

# %%
plt.figure(figsize=(25,50),facecolor='white')
count=1
for i in bbdf.columns:
    if count<=17:
        
        ax=plt.subplot(10,2,count)
        sns.swarmplot(x=bbdf['W'],y=bbdf[i],data=bbdf)
        plt.xlabel(i,fontsize=14)
    count+=1
plt.show()

# %%
sns.scatterplot(x='W',y='SB',data=bbdf)
# Out:
# <Axes: xlabel='W', ylabel='SB'>

# %% [raw]
# # here from the above scatterplot it is clear that target variable win is negativel low correlated with wins

# %% [raw]
# Concluded: Within dataset we observed that some of the features are highly correlated with Target variable and some of the feature are very low correlated with the target feature .Multicollinearity has been seen as some of the feature are highly correlated with each other .

# %%
sns.scatterplot(x='R',y='W',hue='E',data=bbdf)
# Out:
# <Axes: xlabel='R', ylabel='W'>

# %%
for i in bbdf.columns:
    sns.boxplot(bbdf[i])
    plt.show()

# %%
Q1=bbdf['R'].quantile(0.25)
Q2=bbdf['R'].quantile(0.5)
Q3=bbdf['R'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# 550.75
# 818.75

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'R':550.75},max_capping_dict={'R':818.75})
bbdf[['R']]=arb.fit_transform(bbdf[['R']])
plt.boxplot(bbdf['R'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b8a2516710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b8a2517dd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b8a2515b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b8a25293d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b8a2529ed0>],
#  'means': []}

# %%
Q1=bbdf['ERA'].quantile(0.25)
Q2=bbdf['ERA'].quantile(0.5)
Q3=bbdf['ERA'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# 2.8762499999999993
# 5.026250000000001

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'ERA':2.8762499999999993},max_capping_dict={'ERA':5.026250000000001})
bbdf[['ERA']]=arb.fit_transform(bbdf[['ERA']])
plt.boxplot(bbdf['ERA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b8a3baf290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b8a3bb88d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b8a3bae5d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b8a3bb9f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b8a3bbaad0>],
#  'means': []}

# %%
Q1=bbdf['SHO'].quantile(0.25)
Q2=bbdf['SHO'].quantile(0.5)
Q3=bbdf['SHO'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# 3.0
# 19.0

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'SHO':3.0},max_capping_dict={'SHO':19.0})
bbdf[['SHO']]=arb.fit_transform(bbdf[['SHO']])
plt.boxplot(bbdf['SHO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b8a215e690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b8a21a9610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b8a215eb50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b8a21a8590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b8a21ab9d0>],
#  'means': []}

# %%
Q1=bbdf['SV'].quantile(0.25)
Q2=bbdf['SV'].quantile(0.5)
Q3=bbdf['SV'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# 23.0
# 61.0

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'SV':23.0},max_capping_dict={'SV':61.0})
bbdf[['SV']]=arb.fit_transform(bbdf[['SV']])
plt.boxplot(bbdf['SV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b8a21dd9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b8a21dcad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b8a21dcf90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b8a21b8310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b8a21b8f50>],
#  'means': []}

# %%
Q1=bbdf['E'].quantile(0.25)
Q2=bbdf['E'].quantile(0.5)
Q3=bbdf['E'].quantile(0.75)
iqr=Q3-Q1
lowfence=Q1-1.5*iqr
uppfence=Q3+1.5*iqr
print(lowfence)
print(uppfence)
# Out:
# 69.875
# 112.875

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'E':69.875},max_capping_dict={'E':112.875})
bbdf[['E']]=arb.fit_transform(bbdf[['E']])
plt.boxplot(bbdf['E'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b8a205de50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b8a2029dd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b8a205fed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b8a202a710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b8a202a6d0>],
#  'means': []}

# %%
for i in bbdf.columns:
    sns.boxplot(bbdf[i])
    plt.show()

# %%
#Now finally all outlier has been removed

# %%
# Here we are separating independent feature and Target variable
x=bbdf.drop('W',axis=1)

# %%
x
# Out:
#          R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER      ERA  CG  \
# 0   724.00  5575  1497  300  42  139  383   973  104  641  601  3.73000   2
# 1   696.00  5467  1349  277  44  156  439  1264   70  700  653  4.07000   2
# 2   669.00  5439  1395  303  29  141  533  1157   86  640  584  3.67000  11
# 3   622.00  5533  1381  260  27  136  404  1231   68  701  643  3.98000   7
# 4   689.00  5605  1515  289  49  151  455  1259   83  803  746  4.64000   7
# 5   818.75  5509  1480  308  17  232  570  1151   88  670  609  3.80000   7
# 6   764.00  5567  1397  272  19  212  554  1227   63  698  652  4.03000   3
# 7   713.00  5485  1370  246  20  217  418  1331   44  693  646  4.05000   0
# 8   644.00  5485  1383  278  32  167  436  1310   87  642  604  3.74000   1
# 9   748.00  5640  1495  294  33  161  478  1148   71  753  694  4.31000   3
# 10  751.00  5511  1419  279  32  172  503  1233  101  733  680  4.24000   5
# ...

# %%
y=bbdf.iloc[:,-1]

# %%
y
# Out:
# 0      88.000
# 1      86.000
# 2      79.000
# 3     101.000
# 4      86.000
# 5      88.000
# 6      93.000
# 7      77.000
# 8      95.000
# 9      97.000
# 10    112.875
# 11     85.000
# 12     93.000
# 13     94.000
# 14    112.875
# 15     96.000
# 16    112.875
# 17    111.000
# 18    112.875
# 19     90.000
# 20     88.000
# 21     90.000
# 22     77.000
# 23     90.000
# 24    112.875
# 25     75.000
# 26     78.000
# 27     86.000
# 28     92.000
# 29     95.000
# Name: E, dtype: float64

# %%
x
# Out:
#          R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER      ERA  CG  \
# 0   724.00  5575  1497  300  42  139  383   973  104  641  601  3.73000   2
# 1   696.00  5467  1349  277  44  156  439  1264   70  700  653  4.07000   2
# 2   669.00  5439  1395  303  29  141  533  1157   86  640  584  3.67000  11
# 3   622.00  5533  1381  260  27  136  404  1231   68  701  643  3.98000   7
# 4   689.00  5605  1515  289  49  151  455  1259   83  803  746  4.64000   7
# 5   818.75  5509  1480  308  17  232  570  1151   88  670  609  3.80000   7
# 6   764.00  5567  1397  272  19  212  554  1227   63  698  652  4.03000   3
# 7   713.00  5485  1370  246  20  217  418  1331   44  693  646  4.05000   0
# 8   644.00  5485  1383  278  32  167  436  1310   87  642  604  3.74000   1
# 9   748.00  5640  1495  294  33  161  478  1148   71  753  694  4.31000   3
# 10  751.00  5511  1419  279  32  172  503  1233  101  733  680  4.24000   5
# ...

# %%
x.skew()
# Out:
# R      0.284282
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.037969
# CG     0.736845
# SHO    0.218030
# SV     0.612333
# E      0.504019
# dtype: float64

# %%
x=x.applymap(np.cbrt)

# %%
x.skew()
# Out:
# R      0.115627
# AB     0.168524
# H      0.642599
# 2B    -0.327033
# 3B    -0.239420
# HR     0.175310
# BB     0.018373
# SO    -0.412629
# SB     0.049734
# RA    -0.144389
# ER    -0.165952
# ERA   -0.207715
# CG    -1.043632
# SHO   -0.505920
# SV     0.289502
# E      0.358315
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled=StandardScaler()
x=pd.DataFrame(scaled.fit_transform(x),columns =x.columns)

# %%
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.771850  0.849480  1.654199  1.390821  1.020276 -0.775226 -1.599063
# 1   0.226278 -0.709505 -0.978027  0.147858  1.172227 -0.186932 -0.508344
# 2  -0.313849 -1.117032 -0.140129  1.548207 -0.109000 -0.703608  1.130373
# 3  -1.289832  0.245621 -0.393166 -0.815822 -0.311288 -0.883952 -1.178311
# 4   0.087606  1.278953  1.962309  0.804597  1.532952 -0.355325 -0.213911
# 5   2.519849 -0.100814  1.360930  1.808223 -1.510519  2.018459  1.722354
# 6   1.527356  0.734693 -0.104119 -0.131384 -1.238850  1.491597  1.469604
# 7   0.559225 -0.448257 -0.593183 -1.641496 -1.110132  1.626318 -0.905852
# 8  -0.827082 -0.448257 -0.356913  0.203303  0.177676  0.171256 -0.564343
# 9   1.228394  1.778073  1.619812  1.072874  0.269237 -0.022099  0.197479
# 10  1.284772 -0.071906  0.289739  0.258614  0.177676  0.328877  0.629938
# 11  0.867786 -0.825799 -0.721025  0.203303 -0.416196  1.967170  0.337474
# ...

# %% [raw]
# # checking For Multicollinearity among the independent features and it is very important to remove multicollinearity.If the multicollinearity present in the regression model then changes in one variable tend to change in another variable and it will be very difficult for the model to estimate the reltionship between independent variable and dependent variable

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns

# %%
vif
# Out:
#          values features
# 0      9.821368        R
# 1     13.603789       AB
# 2      7.018584        H
# 3      3.993189       2B
# 4      3.166985       3B
# 5      9.694421       HR
# 6      3.889987       BB
# 7      2.573106       SO
# 8      2.034517       SB
# 9    192.828138       RA
# 10  2234.273415       ER
# 11  1638.617436      ERA
# 12     2.753370       CG
# 13     2.906493      SHO
# 14     5.151023       SV
# 15     2.148203        E

# %% [raw]
# # here from the above vif values it is clear that Earned Run feature have very high vif values so this feature has high degree of multicollinearity with other feature (acceptable range for the vif values are between -5 to +5 or 10) so it is better to drop ER from the dataset.

# %%
x.drop('ER',axis=1,inplace=True)

# %%
# now again checking for Multicollinearity

# %%
vif=pd.DataFrame()
vif['values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns

# %%
vif
# Out:
#         values features
# 0     7.993079        R
# 1     4.723546       AB
# 2     7.003317        H
# 3     3.710814       2B
# 4     3.099414       3B
# 5     7.084421       HR
# 6     3.883781       BB
# 7     2.560015       SO
# 8     1.894950       SB
# 9   118.789520       RA
# 10  118.589554      ERA
# 11    2.607765       CG
# 12    2.776704      SHO
# 13    2.313291       SV
# 14    2.140676        E

# %% [raw]
# #here again we have seen that still multicollinearity is present as vif values of RA is higher so we need to drop this feature

# %%
x.drop('RA',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns
vif
# Out:
#       values features
# 0   7.984683        R
# 1   3.644188       AB
# 2   6.655696        H
# 3   3.488838       2B
# 4   2.987049       3B
# 5   6.684175       HR
# 6   3.450990       BB
# 7   2.279280       SO
# 8   1.870322       SB
# 9   4.838268      ERA
# 10  2.486132       CG
# 11  2.673144      SHO
# 12  2.050404       SV
# 13  1.917740        E

# %%
# Now Multicollinearity has been removed from the features

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
for i in x.columns:
    sns.distplot(x[i])
    plt.show()

# %%
x.skew()
# Out:
# R      0.115627
# AB     0.168524
# H      0.642599
# 2B    -0.327033
# 3B    -0.239420
# HR     0.175310
# BB     0.018373
# SO    -0.412629
# SB     0.049734
# RA    -0.144389
# ER    -0.165952
# ERA   -0.207715
# CG    -1.043632
# SHO   -0.505920
# SV     0.289502
# E      0.358315
# dtype: float64

# %%
x.shape
# Out:
# (30, 14)

# %%
y.shape
# Out:
# (30,)

# %%
x.isnull().sum()
# Out:
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
import xgboost
from xgboost import XGBRegressor

# %%
mxac=0
mxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>mxac:
        mxac=acc
        mxrs=i
print('maximum r2 score is',mxac,'at random state',mxrs)
# Out:
# maximum r2 score is 0.9983569447391284 at random state 155

# %%
en=ElasticNet()
en.fit(x_train,y_train)
rdpred_test=en.predict(x_test)
rdpred_train=en.predict(x_train)
print('R2_score',r2_score(y_test,rdpred_test)*100)
print('R2 score on training data',r2_score(y_train,rdpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,rdpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,rdpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,rdpred_test)))
print('cross validation score',cross_val_score(en,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 66.61495057577098
# R2 score on training data 85.70236896233173
# Mean Absolute Error 5.538464704680482
# Mean Squared  Error 46.23713424945219
# Root Mean Absolute Error 6.7997892797830275
# cross validation score 62.71646298490457

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbrpred_test=gbr.predict(x_test)
gbrpred_train=gbr.predict(x_train)
print('R2_score',r2_score(y_test,gbrpred_test))
print('R2 score on training data',r2_score(y_train,gbrpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,gbrpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,gbrpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,gbrpred_test)))
print('cross validation score',cross_val_score(gbr,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 0.9814884401846282
# R2 score on training data 99.99999990095573
# Mean Absolute Error 1.0011924335684388
# Mean Squared  Error 2.563786758179625
# Root Mean Absolute Error 1.601182924646533
# cross validation score 96.87681092937022

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbrpred_test=gbr.predict(x_test)
gbrpred_train=gbr.predict(x_train)
print('R2_score',r2_score(y_test,gbrpred_test))
print('R2 score on training data',r2_score(y_train,gbrpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,gbrpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,gbrpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,gbrpred_test)))
print('cross validation score',cross_val_score(gbr,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 0.98056568666553
# R2 score on training data 99.99999990095573
# Mean Absolute Error 1.0315621904875896
# Mean Squared  Error 2.691584916569464
# Root Mean Absolute Error 1.6406050458807764
# cross validation score 96.80129299914726

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
dtcpred_test=dtc.predict(x_test)

dtcpred_train=dtc.predict(x_train)
print('R2_score',r2_score(y_test,dtcpred_test)*100)
print('R2 score on training data',r2_score(y_train,dtcpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,dtcpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,dtcpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,dtcpred_test)))
print('cross validation score',cross_val_score(dtc,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 87.76293027803545
# R2 score on training data 100.0
# Mean Absolute Error 2.1944444444444446
# Mean Squared  Error 16.947916666666668
# Root Mean Absolute Error 4.116784748643857
# cross validation score 91.645470977409

# %%
etc=ExtraTreesRegressor()
etc.fit(x_train,y_train)
etcpred_test=etc.predict(x_test)
etcpred_train=etc.predict(x_train)
print('R2_score',r2_score(y_test,etcpred_test)*100)
print('R2 score on training data',r2_score(y_train,etcpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,etcpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,etcpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,etcpred_test)))
print('cross validation score',cross_val_score(etc,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 97.77379760322911
# R2 score on training data 100.0
# Mean Absolute Error 1.1745833333333324
# Mean Squared  Error 3.083213020833332
# Root Mean Absolute Error 1.7559080331365113
# cross validation score 98.86449646825565

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
rfrpred_test=rfr.predict(x_test)
rfrpred_train=rfr.predict(x_train)
print('R2_score',r2_score(y_test,rfrpred_test)*100)
print('R2 score on training data',r2_score(y_train,rfrpred_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,rfrpred_test))
print('Mean Squared  Error',mean_squared_error(y_test,rfrpred_test))
print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,rfrpred_test)))
print('cross validation score',cross_val_score(rfr,x,y,cv=5,scoring='r2').mean()*100)
# Out:
# R2_score 93.40689422618898
# R2 score on training data 98.22604696932609
# Mean Absolute Error 2.538333333333333
# Mean Squared  Error 9.131222569444446
# Root Mean Absolute Error 3.021791284891206
# cross validation score 91.93105204791206

# %%
score1=cross_val_score(lr,x,y,cv=10)
print(score1)
print(score1.mean()*100)
print('difference between r2 score and cross validation score is ',r2_score(y_test,pred)-score1.mean())
# Out:
# [0.96474188 0.9783812  0.97081349 0.99765967 0.99446198 0.98661364
#  0.99866451 0.9574793  0.99670045 0.97528289]
# 98.2079899874243
# difference between r2 score and cross validation score is  0.010517539369506723

# %%
score2=cross_val_score(en,x,y,cv=5)
print(score2)
print(score2.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,rdpred_test)-score2.mean())*100)
# Out:
# [ 0.63858617  0.81957262 -0.00320792  0.84712307  0.83374921]
# 0.6271646298490456
# difference between r2 score and cross validation score is  3.8984875908664174

# %%
score3=cross_val_score(rfr,x,y,cv=10)
print(score3)
print(score3.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,rfrpred_test)-score3.mean())*100)
# Out:
# [0.99169403 0.71234803 0.96806101 0.97070048 0.96532191 0.963001
#  0.99438241 0.97563609 0.91930653 0.86837351]
# 0.9328825022722629
# difference between r2 score and cross validation score is  0.1186439989626975

# %%
gbrscore=cross_val_score(gbr,x,y,cv=5)
print(gbrscore)
print(gbrscore.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,gbrpred_test)-gbrscore.mean())*100)
# Out:
# [0.88446717 0.99746958 0.96761268 0.98225098 0.97907647]
# 0.9621753780843783
# difference between r2 score and cross validation score is  1.839030858115176

# %%
etcscore=cross_val_score(etc,x,y,cv=5)
print(etcscore)
print(etccore.mean())
print('difference between r2 score and cross validation score is ',(r2_score(y_test,etcpred_test)-etcscore.mean())*100)
# Out:
# [0.99723241 0.99737017 0.96072436 0.99553671 0.97945168]
# 0.9783091629138545
# difference between r2 score and cross validation score is  -0.8325086730207043

# %%
models=[lr,en,gbr,etc,rfr,dtc]

# %%
for model in models:
    print(f'PERFORMANCE EVALUATION FOR {model}')
    model.fit(x_train,y_train)
    pred_test=model.predict(x_test)
    pred_train=model.predict(x_train)
    print('R2_score',r2_score(y_test,pred_test)*100)
    print('R2 score on training data',r2_score(y_train,pred_train)*100)
    print('Mean Absolute Error',mean_absolute_error(y_test,pred_test))
    print('Mean Squared  Error',mean_squared_error(y_test,rfrpred_test))
    print('Root Mean Absolute Error',np.sqrt(mean_squared_error(y_test,pred_test)))
    print('cross validation score',cross_val_score(model,x,y,cv=5,scoring='r2').mean()*100)
    print('*'*50)
# Out:
# PERFORMANCE EVALUATION FOR LinearRegression()
# R2_score 99.25974392437497
# R2 score on training data 99.93145598687082
# Mean Absolute Error 0.8673530929988781
# Mean Squared  Error 9.131222569444446
# Root Mean Absolute Error 1.012535906229851
# cross validation score 98.88979427922295
# **************************************************
# PERFORMANCE EVALUATION FOR ElasticNet()
# R2_score 66.61495057577098
# R2 score on training data 85.70236896233173
# Mean Absolute Error 5.538464704680482
# Mean Squared  Error 9.131222569444446
# Root Mean Absolute Error 6.7997892797830275
# cross validation score 62.71646298490457
# **************************************************
# PERFORMANCE EVALUATION FOR GradientBoostingRegressor()
# R2_score 98.98513629441746
# R2 score on training data 99.99999990095573
# Mean Absolute Error 0.8452802323029118
# Mean Squared  Error 9.131222569444446
# Root Mean Absolute Error 1.1855593590827576
# cross validation score 96.06362410104211
# ...

# %%
for model in models:
    print(f'cross validation score for the {model}')
    predd_test=model.predict(x_test)
    score=cross_val_score(model,x,y,cv=5)
    print(score)
    print(score.mean()*100)
    print('difference between r2 score and cross validation score is ',(r2_score(y_test,predd_test)-score.mean())*100)
    print('*'*100)
# Out:
# cross validation score for the LinearRegression()
# [0.98879806 0.9822127  0.9898823  0.98939761 0.99419904]
# 98.88979427922295
# difference between r2 score and cross validation score is  0.36994964515202344
# ****************************************************************************************************
# cross validation score for the ElasticNet()
# [ 0.63858617  0.81957262 -0.00320792  0.84712307  0.83374921]
# 62.71646298490457
# difference between r2 score and cross validation score is  3.8984875908664174
# ****************************************************************************************************
# cross validation score for the GradientBoostingRegressor()
# [0.90803591 0.99686702 0.95796522 0.98081962 0.97870274]
# 96.44781023005538
# difference between r2 score and cross validation score is  2.5373260643620776
# ****************************************************************************************************
# ...

# %% [raw]
# CONCLUSION : BASED ON THE ABOVE OBSERVATION LINEAR REGRESSION MODEL IS GIVING BETTER PERFORMANCE AMONG ALL OTHER MODEL
#     cross validation score for the LinearRegression()
# [0.98879806 0.9822127  0.9898823  0.98939761 0.99419904]
# 98.88979427922295
# difference between r2 score and cross validation score is  0.36994964515202344
#
# Differnce between r2 score and cross validation is very less
#
# PERFORMANCE EVALUATION FOR LinearRegression()
# R2_score 99.25974392437497
# R2 score on training data 99.93145598687082
# Mean Absolute Error 0.8673530929988781
# Mean Squared  Error 9.131222569444446
# Root Mean Absolute Error 1.012535906229851
# cross validation score 98.88979427922295
#
#
# If model gives 99% accuracy on training phase and less on testing data in that case there might be chance that model is overfitted but in my case cross validation score is also 99% means model is working fine on unseen data also

# %%
            HYPER PARAMETER TUNING FOR MY MODEL USING GRID SEARCH CV

# %%
from sklearn.model_selection import GridSearchCV

parameters = {"fit_intercept": [True, False]
                           }

model = LinearRegression()

grid_search = GridSearchCV(model, parameters, cv=5, scoring='neg_mean_squared_error')


grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False]},
#              scoring='neg_mean_squared_error')

# %%
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# %%
best_params
# Out:
# {'fit_intercept': True}

# %%
best_model
# Out:
# LinearRegression()

# %%
final_model=LinearRegression(fit_intercept=True,n_jobs=-1)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=r2_score(y_test,pred)
print(acc)
score=cross_val_score(final_model,x,y,cv=5)
print(score)
print(score.mean()*100)
print('difference between r2 score and cross validation score is ',(acc-score.mean())*100)
# Out:
# 0.9925974392437498
# [0.98879806 0.9822127  0.9898823  0.98939761 0.99419904]
# 98.88979427922295
# difference between r2 score and cross validation score is  0.36994964515202344

# %%
import joblib

# %%
joblib.dump(final_model,'Base_Ball_case.pkl')
# Out:
# ['Base_Ball_case.pkl']

# %%
model=joblib.load('Base_ball_case.pkl')

# %%
df=pd.DataFrame()

# %%
prediction=model.predict(x_test)

# %%
dummy_test=np.array(y_test)

# %%
df['orginal']=dummy_test
df['prediction']=prediction
df
# Out:
#    orginal  prediction
# 0  111.000  110.674003
# 1   93.000   94.444214
# 2   86.000   85.382295
# 3   97.000   97.433538
# 4   96.000   97.437836
# 5  112.875  114.433028
# 6   90.000   90.075704
# 7   78.000   76.783729
# 8  112.875  112.178116

# %% [raw]
# # here from the above prediction we conclude my model predicting accurately for unseen data also
